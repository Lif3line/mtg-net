# %%
import pandas as pd
import numpy as np
import json

file_path = "data/AllSets.json"

with open(file_path) as data_file:  
    data = json.load(data_file)
    
df=pd.DataFrame(data)

# %%
i = 0
for key in data:
    print ("key: {}".format(key))
    i += 1
    
print("\nSets: {}".format(i))
# Out:
# key: C16
# key: 8ED
# key: 2ED
# key: p15A
# key: pREL
# key: ZEN
# key: ONS
# key: KLD
# key: AER
# key: pCMP
# key: DIS
# key: pWOR
# key: ODY
# key: MD1
# key: MGB
# key: KTK
# key: EXO
# key: MBS
# key: W16
# key: BFZ
# key: NPH
# key: M13
# key: TMP
# key: SCG
# key: OGW
# key: MM2
# key: AKH
# key: pFNM
# key: JOU
# key: DKM
# key: BRB
# key: 10E
# key: SHM
# key: DGM
# key: CON
# key: pPOD
# key: DD2
# key: TOR
# key: LRW
# key: pELP
# key: p2HG
# key: RAV
# key: DD3_EVG
# key: 9ED
# key: V16
# key: FRF_UGIN
# key: V09
# key: MED
# key: M14
# key: WTH
# key: BOK
# key: V15
# key: ISD
# key: pWCQ
# key: pDRC
# key: EMA
# key: CHK
# key: DPA
# key: FEM
# key: ITP
# key: V11
# key: 4ED
# key: DDL
# key: DD3_DVD
# key: S00
# key: pWPN
# key: GTC
# key: C13
# key: DDD
# key: CSP
# key: PO2
# key: PD3
# key: MOR
# key: pJGP
# key: THS
# key: LGN
# key: V14
# key: EMN
# key: S99
# key: DDK
# key: LEA
# key: RQS
# key: M11
# key: CMD
# key: pMPR
# key: BTD
# key: pSUM
# key: PLS
# key: WWK
# key: ARB
# key: VIS
# key: RTR
# key: GPT
# key: C14
# key: pHHO
# key: HOP
# key: ORI
# key: EXP
# key: DD3_GVL
# key: DDC
# key: pARL
# key: LEB
# key: pMEI
# key: DDE
# key: CED
# key: EVE
# key: DRK
# key: PTK
# key: pALP
# key: HML
# key: M15
# key: SOM
# key: EVG
# key: ALL
# key: UDS
# key: DTK
# key: POR
# key: CNS
# key: DDR
# key: PLC
# key: PD2
# key: pGRU
# key: JUD
# key: pMGD
# key: pCEL
# key: H09
# key: ALA
# key: pPRO
# key: TPR
# key: pGTW
# key: DDN
# key: 5ED
# key: LEG
# key: ICE
# key: ME4
# key: CST
# key: DDH
# key: MRD
# key: MMQ
# key: 5DN
# key: DDP
# key: STH
# key: UNH
# key: CHR
# key: DST
# key: ARN
# key: MMA
# key: DDJ
# key: PC2
# key: DKA
# key: VAN
# key: TSP
# key: C15
# key: CN2
# key: ULG
# key: AVR
# key: MPS
# key: PCA
# key: pLGM
# key: DDO
# key: NMS
# key: SOK
# key: DDQ
# key: pWOS
# key: V13
# key: ARC
# key: V10
# key: MPS_AKH
# key: 6ED
# key: FRF
# key: pGPX
# key: MM3
# key: ATQ
# key: ME2
# key: TSB
# key: USG
# key: DD3_JVC
# key: APC
# key: CPK
# key: CEI
# key: VMA
# key: BNG
# key: pSUS
# key: 7ED
# key: 3ED
# key: pLPA
# key: CM1
# key: FUT
# key: ROE
# key: INV
# key: MIR
# key: DRB
# key: SOI
# key: DDM
# key: PCY
# key: ME3
# key: V12
# key: DDF
# key: ATH
# key: pPRE
# key: UGL
# key: M10
# key: DDG
# key: M12
# key: DDI
# key: DDS
#
# Sets: 206

# %%
print(data["LEA"]["cards"])
# Out:
# [{'colorIdentity': ['U'], 'imageName': 'air elemental', 'artist': 'Richard Thomas', 'text': 'Flying', 'rarity': 'Uncommon', 'cmc': 5, 'power': '4', 'manaCost': '{3}{U}{U}', 'colors': ['Blue'], 'toughness': '4', 'mciNumber': '47', 'flavor': 'These spirits of the air are winsome and wild, and cannot be truly contained. Only marginally intelligent, they often substitute whimsy for strategy, delighting in mischief and mayhem.', 'name': 'Air Elemental', 'type': 'Creature — Elemental', 'types': ['Creature'], 'id': '926234c2fe8863f49220a878346c4c5ca79b6046', 'multiverseid': 94, 'layout': 'normal', 'subtypes': ['Elemental']}, {'colorIdentity': ['U'], 'id': 'aa74b7dc3b30b2e7559598f983543755e226811d', 'artist': 'Mark Poole', 'reserved': True, 'rarity': 'Rare', 'cmc': 1, 'manaCost': '{U}', 'colors': ['Blue'], 'imageName': 'ancestral recall', 'mciNumber': '48', 'multiverseid': 95, 'name': 'Ancestral Recall', 'type': 'Instant', 'types': ['Instant'], 'text': 'Target player draws three cards.', 'layout': 'normal'}, {'colorIdentity': ['U'], 'id': '9d91ef4896ab4c1a5611d4d06971fc8026dd2f3f', 'artist': 'Douglas Shuler', 'text': "Enchant artifact\nAs long as enchanted artifact isn't a creature, it's an artifact creature with power and toughness each equal to its converted mana cost.", 'rarity': 'Uncommon', 'cmc': 4, 'manaCost': '{3}{U}', 'colors': ['Blue'], 'imageName': 'animate artifact', 'mciNumber': '49', 'multiverseid': 96, 'name': 'Animate Artifact', 'type': 'Enchantment — Aura', 'types': ['Enchantment'], 'layout': 'normal', 'subtypes': ['Aura']}, {'colorIdentity': ['B'], 'id': 'd8b74ea7f050c8c05588e002f0264643fc90209b', 'artist': 'Anson Maddocks', 'text': 'Enchant creature card in a graveyard\nWhen Animate Dead enters the battlefield, if it\'s on the battlefield, it loses "enchant creature card in a graveyard" and gains "enchant creature put onto the battlefield with Animate Dead." Return enchanted creature card to the battlefield under your control and attach Animate Dead to it. When Animate Dead leaves the battlefield, that creature\'s controller sacrifices it.\nEnchanted creature gets -1/-0.', 'rarity': 'Uncommon', 'cmc': 2, 'manaCost': '{1}{B}', 'colors': ['Black'], 'imageName': 'animate dead', 'mciNumber': '1', 'multiverseid': 48, 'name': 'Animate Dead', 'type': 'Enchantment — Aura', 'types': ['Enchantment'], 'layout': 'normal', 'subtypes': ['Aura']}, {'colorIdentity': ['W'], 'id': '6ba9537d0f1733e4a01927bdf60bfb5122e5a709', 'artist': 'Dan Frazier', 'text': "Enchant Wall\nEnchanted Wall can attack as though it didn't have defender.", 'rarity': 'Rare', 'cmc': 1, 'manaCost': '{W}', 'colors': ['White'], 'imageName': 'animate wall', 'mciNumber': '185', 'multiverseid': 232, 'name': 'Animate Wall', 'type': 'Enchantment — Aura', 'types': ['Enchantment'], 'layout': 'normal', 'subtypes': ['Aura']}, {'id': '8a5d85644f546525433c4472b76c3b0ebb495b33', 'imageName': 'ankh of mishra', 'artist': 'Amy Weber', 'name': 'Ankh of Mishra', 'rarity': 'Rare', 'cmc': 2, 'manaCost': '{2}', 'mciNumber': '230', 'multiverseid': 1, 'text': "Whenever a land enters the battlefield, Ankh of Mishra deals 2 damage to that land's controller.", 'type': 'Artifact', 'types': ['Artifact'], 'layout': 'normal'}, {'colorIdentity': ['W'], 'id': 'dad22f637f5738675195185633f48499c03f8adc', 'artist': 'Jesper Myrfors', 'text': 'Destroy all lands.', 'rarity': 'Rare', 'cmc': 4, 'manaCost': '{3}{W}', 'colors': ['White'], 'imageName': 'armageddon', 'mciNumber': '186', 'multiverseid': 233, 'name': 'Armageddon', 'type': 'Sorcery', 'types': ['Sorcery'], 'layout': 'normal'}, {'colorIdentity': ['G'], 'id': '54571e7147917bcb661a87a1fb68070088756ca7', 'artist': 'Jeff A. Menges', 'text': 'Enchant creature\nEnchanted creature gets +X/+Y, where X is half the number of Forests you control, rounded down, and Y is half the number of Forests you control, rounded up.', 'rarity': 'Rare', 'cmc': 2, 'manaCost': '{1}{G}', 'colors': ['Green'], 'imageName': 'aspect of wolf', 'mciNumber': '93', 'multiverseid ...

# %%
all_cards = pd.DataFrame(df, index=["cards"])
pd.DataFrame(all_cards, index=["name"])
# Out:
#       10E  2ED  3ED  4ED  5DN  5ED  6ED  7ED  8ED  9ED ...  pPOD pPRE pPRO  \
# name  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN ...   NaN  NaN  NaN
#
#      pREL pSUM pSUS pWCQ pWOR pWOS pWPN
# name  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [1 rows x 206 columns]
